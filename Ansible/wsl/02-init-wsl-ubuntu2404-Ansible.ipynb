# %% [markdown]
# # Ansible環境作成
# python 仮想環境を作成して ansible をインストール、カーネルとしてインストールする
# WSL上のJupyterで実行

# %%
# !python3 -m venv ~/venv/ansible

# %%
# !source ~/venv/ansible/bin/activate && pip install --upgrade pip ansible-core ansible-runner ipykernel bash_kernel

# %%
# !source ~/venv/ansible/bin/activate && ansible-galaxy collection install community.general

# %%
# !echo 'export PATH="/home/sakaztk/venv/ansible/bin:$PATH"' >> ~/.bashrc

# %%
# !source ~/.bashrc

# %%
# !source ~/venv/ansible/bin/activate && python -m bash_kernel.install

# %%
# !source ~/venv/ansible/bin/activate && python -m ipykernel install --user --name ansible --display-name 'Python 3 (ansible)'
