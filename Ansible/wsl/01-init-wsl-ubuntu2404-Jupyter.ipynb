# %% [markdown]
# # 初期設定
# * wsl --install ubuntu でユーザー名パスワードの設定
# * ubuntu内でsudo設定だけする
# ````
# echo 'sakaztk ALL=(ALL) NOPASSWD:ALL' | sudo tee /etc/sudoers.d/sakaztk
# sudo chmod 440 /etc/sudoers.d/sakaztk
# ````
# * 以降をホストWindowsから実行

# %%
wsl sudo apt-get update

# %%
wsl sudo apt-get upgrade -y

# %%
wsl sudo apt-get install -y python3-pip

# %%
wsl sudo apt-get install -y pipx

# %% [markdown]
# # pipx で jupyter 一式をインストール

# %%
wsl pipx install jupyter-core

# %%
wsl pipx inject jupyter-core jupyterlab notebook ipywidgets qtconsole
