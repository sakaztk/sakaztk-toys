# %%
# !molecule create
# Out:
# WARNING  Driver podman does not provide a schema.
# WARNING  Driver podman does not provide a schema.
# INFO     default ➜ discovery: scenario test matrix: dependency, create, prepare
# INFO     default ➜ prerun: Performing prerun with role_name_check=0...
# WARNING  Another version of 'community.general' 11.4.0 was found installed in /home/sakaztk/venv/ansible/lib/python3.12/site-packages/ansible_collections, only the first one will be used, 11.4.0 (/home/sakaztk/.ansible/collections/ansible_collections).
# INFO     default ➜ dependency: Executing
# WARNING  default ➜ dependency: Missing roles requirements file: requirements.yml
# WARNING  default ➜ dependency: Missing collections requirements file: collections.yml
# WARNING  default ➜ dependency: Executed: 2 missing (Remove from create_sequence to suppress)
# INFO     default ➜ create: Executing
# INFO     Sanity checks: 'podman'
# ...

# %%
# !molecule converge
# Out:
# WARNING  Driver podman does not provide a schema.
# WARNING  Driver podman does not provide a schema.
# INFO     default ➜ discovery: scenario test matrix: dependency, create, prepare, converge
# INFO     default ➜ prerun: Performing prerun with role_name_check=0...
# WARNING  Another version of 'community.general' 11.4.0 was found installed in /home/sakaztk/venv/ansible/lib/python3.12/site-packages/ansible_collections, only the first one will be used, 11.4.0 (/home/sakaztk/.ansible/collections/ansible_collections).
# INFO     default ➜ dependency: Executing
# WARNING  default ➜ dependency: Missing roles requirements file: requirements.yml
# WARNING  default ➜ dependency: Missing collections requirements file: collections.yml
# WARNING  default ➜ dependency: Executed: 2 missing (Remove from converge_sequence to suppress)
# INFO     default ➜ create: Executing
# WARNING  default ➜ create: Skipping, instances already created.
# ...

# %%
# !molecule idempotence
# Out:
# WARNING  Driver podman does not provide a schema.
# WARNING  Driver podman does not provide a schema.
# INFO     default ➜ discovery: scenario test matrix: idempotence
# INFO     default ➜ prerun: Performing prerun with role_name_check=0...
# WARNING  Another version of 'community.general' 11.4.0 was found installed in /home/sakaztk/venv/ansible/lib/python3.12/site-packages/ansible_collections, only the first one will be used, 11.4.0 (/home/sakaztk/.ansible/collections/ansible_collections).
# INFO     default ➜ idempotence: Executing
# INFO     Sanity checks: 'podman'
# [WARNING]: Deprecation warnings can be disabled by setting `deprecation_warnings=False` in ansible.cfg.
# [DEPRECATION WARNING]: DEFAULT_MANAGED_STR option. Reason: The `ansible_managed` variable can be set just like any other variable, or a different variable can be used.
# ...

# %%
# !molecule verify
# Out:
# WARNING  Driver podman does not provide a schema.
# WARNING  Driver podman does not provide a schema.
# INFO     default ➜ discovery: scenario test matrix: verify
# INFO     default ➜ prerun: Performing prerun with role_name_check=0...
# WARNING  Another version of 'community.general' 11.4.0 was found installed in /home/sakaztk/venv/ansible/lib/python3.12/site-packages/ansible_collections, only the first one will be used, 11.4.0 (/home/sakaztk/.ansible/collections/ansible_collections).
# INFO     default ➜ verify: Executing
# INFO     Sanity checks: 'podman'
# [WARNING]: Deprecation warnings can be disabled by setting `deprecation_warnings=False` in ansible.cfg.
# [DEPRECATION WARNING]: DEFAULT_MANAGED_STR option. Reason: The `ansible_managed` variable can be set just like any other variable, or a different variable can be used.
# Alternatives: Set the `ansible_managed` variable, or use any custom variable in templates. This feature will be removed from ansible-core version 2.23.
#
# ...

# %%
# !molecule destroy
# Out:
# WARNING  Driver podman does not provide a schema.
# WARNING  Driver podman does not provide a schema.
# INFO     default ➜ discovery: scenario test matrix: dependency, cleanup, destroy
# INFO     default ➜ prerun: Performing prerun with role_name_check=0...
# WARNING  Another version of 'community.general' 11.4.0 was found installed in /home/sakaztk/venv/ansible/lib/python3.12/site-packages/ansible_collections, only the first one will be used, 11.4.0 (/home/sakaztk/.ansible/collections/ansible_collections).
# INFO     default ➜ dependency: Executing
# WARNING  default ➜ dependency: Missing roles requirements file: requirements.yml
# WARNING  default ➜ dependency: Missing collections requirements file: collections.yml
# WARNING  default ➜ dependency: Executed: 2 missing (Remove from destroy_sequence to suppress)
# INFO     default ➜ cleanup: Executing
# WARNING  default ➜ cleanup: Executed: Missing playbook (Remove from destroy_sequence to suppress)
# ...
